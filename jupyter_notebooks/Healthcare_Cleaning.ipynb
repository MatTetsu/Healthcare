# %% [markdown]
# **Healthcare cleaning**

# %% [markdown]
# My objective is to clean the dataset so it can be used for visualzations.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# Here I have imported all the languages I will need. If I need to import anymore, I will import them under this cell, but above the cleaning.

# %%
import random
import base64
from IPython.display import HTML
import io

# %% [markdown]
# "import random" was used to randomly assign patients ID numbers.
# "import base64" was used to get the downloadable files of the cleaned data for both CSV and XLSX.
# "import IPython.display" was used to get the downloadable files of the cleaned data for both CSV and XLSX.
# "import io" was used to get the downloadable file of the cleaned data for XLSX.

# %%
df = pd.read_csv('../Datasets/healthcare_dataset.csv')

# %%
df
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 0            2024-01-31     Matthew Smith               Sons and Miller
# 1            2019-08-20   Samantha Davies                       Kim Inc
# 2            2022-09-22  Tiffany Mitchell                      Cook PLC
# 3            2020-11-18       Kevin Wells    Hernandez Rogers and Vang,
# 4            2022-09-19    Kathleen Hanna                   White-White
# ...                 ...               ...                           ...
# 55495        2020-08-16     Joshua Jarvis                Jones-Thompson
# 55496        2020-01-23   Taylor Sullivan                  Tucker-Moyer
# 55497        2020-07-13    Joe Jacobs DVM  and Mahoney Johnson Vasquez,
# 55498        2019-05-25    Kimberly Curry      Jackson Todd and Castro,
# 55499        2024-04-02     Dennis Warren                Henry Sons and
#
#       Insurance Provider  Billing Amount  Room Number Admission Type  \
# 0             Blue Cross    18856.281306          328         Urgent
# 1               Medicare    33643.327287          265      Emergency
# 2                  Aetna    27955.096079          205      Emergency
# 3               Medicare    37909.782410          450       Elective
# 4                  Aetna    14238.317814          458         Urgent
# ...                  ...             ...          ...            ...
# 55495         Blue Cross     2650.714952          417       Elective
# 55496              Cigna    31457.797307          316       Elective
# 55497   UnitedHealthcare    27620.764717          347         Urgent
# 55498           Medicare    32451.092358          321       Elective
# 55499              Aetna     4010.134172          448         Urgent
#
#       Discharge Date   Medication  Test Results
# 0         2024-02-02  Paracetamol        Normal
# 1         2019-08-26    Ibuprofen  Inconclusive
# 2         2022-10-07      Aspirin        Normal
# 3         2020-12-18    Ibuprofen      Abnormal
# 4         2022-10-09   Penicillin      Abnormal
# ...              ...          ...           ...
# 55495     2020-09-15   Penicillin      Abnormal
# 55496     2020-02-01      Aspirin        Normal
# 55497     2020-08-10    Ibuprofen      Abnormal
# 55498     2019-05-31    Ibuprofen      Abnormal
# 55499     2024-04-29    Ibuprofen      Abnormal
#
# [55500 rows x 15 columns]

# %% [markdown]
# Here I have imported the dataframe I will work on.

# %%
df = df[:10000]

# %% [markdown]
# Here I have dropped it to the top 10,000 rows so that I am working with a smaller dataset. The later visualisations will be affected by the smaller size of the dataset. This may cause an anomalies within the dataset to standout more with the visualisatons.

# %%
df
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 9995         David JoNEs   51  Female         O-         Arthritis
# 9996       NICOle BRooKS   61    Male         B-          Diabetes
# 9997         MIKE TayloR   25    Male         B-            Cancer
# 9998   ReBeccA ramos ddS   71    Male         A-      Hypertension
# 9999  rebeCCA stEPHenSOn   24    Male         A+      Hypertension
#
#      Date of Admission            Doctor                       Hospital  \
# 0           2024-01-31     Matthew Smith                Sons and Miller
# 1           2019-08-20   Samantha Davies                        Kim Inc
# 2           2022-09-22  Tiffany Mitchell                       Cook PLC
# 3           2020-11-18       Kevin Wells     Hernandez Rogers and Vang,
# 4           2022-09-19    Kathleen Hanna                    White-White
# ...                ...               ...                            ...
# 9995        2019-09-25       Isaac Silva                  Rice and Sons
# 9996        2020-06-03        Jose Cohen   Johnson, Adkins and Ferguson
# 9997        2024-03-14      Michael Hess                   Kramer-Hogan
# 9998        2023-08-22   Cheryl Faulkner  Williams Barnes and Fletcher,
# 9999        2023-04-24    Jonathan Owens                      Jones Ltd
#
#      Insurance Provider  Billing Amount  Room Number Admission Type  \
# 0            Blue Cross    18856.281306          328         Urgent
# 1              Medicare    33643.327287          265      Emergency
# 2                 Aetna    27955.096079          205      Emergency
# 3              Medicare    37909.782410          450       Elective
# 4                 Aetna    14238.317814          458         Urgent
# ...                 ...             ...          ...            ...
# 9995              Cigna     5127.438142          106         Urgent
# 9996              Aetna    47855.349591          122      Emergency
# 9997   UnitedHealthcare    40787.180500          440       Elective
# 9998         Blue Cross    25979.751629          319      Emergency
# 9999              Cigna    19782.638991          438      Emergency
#
#      Discharge Date   Medication  Test Results
# 0        2024-02-02  Paracetamol        Normal
# 1        2019-08-26    Ibuprofen  Inconclusive
# 2        2022-10-07      Aspirin        Normal
# 3        2020-12-18    Ibuprofen      Abnormal
# 4        2022-10-09   Penicillin      Abnormal
# ...             ...          ...           ...
# 9995     2019-10-03    Ibuprofen        Normal
# 9996     2020-06-04  Paracetamol        Normal
# 9997     2024-03-28   Penicillin  Inconclusive
# 9998     2023-09-03      Lipitor  Inconclusive
# 9999     2023-05-23    Ibuprofen  Inconclusive
#
# [10000 rows x 15 columns]

# %% [markdown]
# Here I have checked to see that my sampling of the dataset worked.

# %%
df.isna().any()
# Out:
# Name                  False
# Age                   False
# Gender                False
# Blood Type            False
# Medical Condition     False
# Date of Admission     False
# Doctor                False
# Hospital              False
# Insurance Provider    False
# Billing Amount        False
# Room Number           False
# Admission Type        False
# Discharge Date        False
# Medication            False
# Test Results          False
# dtype: bool

# %% [markdown]
# Here I have checked for any null cells in the data.

# %%
duplicates = df.duplicated()
print("number of duplicate rows: ", duplicates.sum())

df[duplicates]
# Out:
# number of duplicate rows:  0
# Empty DataFrame
# Columns: [Name, Age, Gender, Blood Type, Medical Condition, Date of Admission, Doctor, Hospital, Insurance Provider, Billing Amount, Room Number, Admission Type, Discharge Date, Medication, Test Results]
# Index: []

# %% [markdown]
# Here is says that there is no dupliacted rows within the dataset. Although this maybe true here, by sorting the names alphabetically, I found duplicated rows, with differing ages. At the moment I will leave it, but may come back to this later, when I know what to do properly.

# %%
df["Age Range"] = np.nan
df["Patient ID"] = np.nan
df.drop(columns=["Gender"], inplace=True)
# Out:
# C:\Users\matte\AppData\Local\Temp\ipykernel_25360\1068108559.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Age Range"] = np.nan
# C:\Users\matte\AppData\Local\Temp\ipykernel_25360\1068108559.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Patient ID"] = np.nan
# C:\Users\matte\AppData\Local\Temp\ipykernel_25360\1068108559.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=["Gender"], inplace=True)

# %%
df
# Out:
#                     Name  Age Blood Type Medical Condition Date of Admission  \
# 0          Bobby JacksOn   30         B-            Cancer        2024-01-31
# 1           LesLie TErRy   62         A+           Obesity        2019-08-20
# 2            DaNnY sMitH   76         A-           Obesity        2022-09-22
# 3           andrEw waTtS   28         O+          Diabetes        2020-11-18
# 4          adrIENNE bEll   43        AB+            Cancer        2022-09-19
# ...                  ...  ...        ...               ...               ...
# 9995         David JoNEs   51         O-         Arthritis        2019-09-25
# 9996       NICOle BRooKS   61         B-          Diabetes        2020-06-03
# 9997         MIKE TayloR   25         B-            Cancer        2024-03-14
# 9998   ReBeccA ramos ddS   71         A-      Hypertension        2023-08-22
# 9999  rebeCCA stEPHenSOn   24         A+      Hypertension        2023-04-24
#
#                 Doctor                       Hospital Insurance Provider  \
# 0        Matthew Smith                Sons and Miller         Blue Cross
# 1      Samantha Davies                        Kim Inc           Medicare
# 2     Tiffany Mitchell                       Cook PLC              Aetna
# 3          Kevin Wells     Hernandez Rogers and Vang,           Medicare
# 4       Kathleen Hanna                    White-White              Aetna
# ...                ...                            ...                ...
# 9995       Isaac Silva                  Rice and Sons              Cigna
# 9996        Jose Cohen   Johnson, Adkins and Ferguson              Aetna
# 9997      Michael Hess                   Kramer-Hogan   UnitedHealthcare
# 9998   Cheryl Faulkner  Williams Barnes and Fletcher,         Blue Cross
# 9999    Jonathan Owens                      Jones Ltd              Cigna
#
#       Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# 0       18856.281306          328         Urgent     2024-02-02  Paracetamol
# 1       33643.327287          265      Emergency     2019-08-26    Ibuprofen
# 2       27955.096079          205      Emergency     2022-10-07      Aspirin
# 3       37909.782410          450       Elective     2020-12-18    Ibuprofen
# 4       14238.317814          458         Urgent     2022-10-09   Penicillin
# ...              ...          ...            ...            ...          ...
# 9995     5127.438142          106         Urgent     2019-10-03    Ibuprofen
# 9996    47855.349591          122      Emergency     2020-06-04  Paracetamol
# 9997    40787.180500          440       Elective     2024-03-28   Penicillin
# 9998    25979.751629          319      Emergency     2023-09-03      Lipitor
# 9999    19782.638991          438      Emergency     2023-05-23    Ibuprofen
#
#       Test Results  Age Range  Patient ID
# 0           Normal        NaN         NaN
# 1     Inconclusive        NaN         NaN
# 2           Normal        NaN         NaN
# 3         Abnormal        NaN         NaN
# 4         Abnormal        NaN         NaN
# ...            ...        ...         ...
# 9995        Normal        NaN         NaN
# 9996        Normal        NaN         NaN
# 9997  Inconclusive        NaN         NaN
# 9998  Inconclusive        NaN         NaN
# 9999  Inconclusive        NaN         NaN
#
# [10000 rows x 16 columns]

# %% [markdown]
# Here, I have added Age Range, this will allow me to use box plots, and bar graphs better, as there will be a higher collection in the age range over the smaller collection of individual ages. I have also added a Patient ID, this is so that later on I can remove the names column from the dataset, for ethics reasons. I have elected to remove Gender for ethics reasons, the main reason I dropped the gender column was because I couldn't work out a way to make sure it was properly sorted, ideally I would be able to clean it if I had access to all the patients information. I had also planned to drop the Room Number column as it was not going to be used for visualisations, but if this had to be given to more people, especially doctors, it was information that would be linked to their patient ID.

# %%
df = df.iloc[:10000].copy()
to_drop = []
for idx, age in df["Age"].items():
    if age < 18:
        to_drop.append(idx)
    elif 18 <= age < 30:
        df.loc[idx, "Age Range"] = "18-29"
    elif 30 <= age < 45:
        df.loc[idx, "Age Range"] = "30-44"
    elif 45 <= age < 60:
        df.loc[idx, "Age Range"] = "45-59"
    else:
        df.loc[idx, "Age Range"] = "60+"
df.drop(index=to_drop, inplace=True)
# Out:
# C:\Users\matte\AppData\Local\Temp\ipykernel_25360\3848532871.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '30-44' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[idx, "Age Range"] = "30-44"

# %% [markdown]
# Here I have made an if statement to drop each person under the age of 18, and add age ranges for everyone over 18. The reason I have dropped everyone who was under the age of 18 was for ethical reasons.

# %%
df
# Out:
#                     Name  Age Blood Type Medical Condition Date of Admission  \
# 0          Bobby JacksOn   30         B-            Cancer        2024-01-31
# 1           LesLie TErRy   62         A+           Obesity        2019-08-20
# 2            DaNnY sMitH   76         A-           Obesity        2022-09-22
# 3           andrEw waTtS   28         O+          Diabetes        2020-11-18
# 4          adrIENNE bEll   43        AB+            Cancer        2022-09-19
# ...                  ...  ...        ...               ...               ...
# 9995         David JoNEs   51         O-         Arthritis        2019-09-25
# 9996       NICOle BRooKS   61         B-          Diabetes        2020-06-03
# 9997         MIKE TayloR   25         B-            Cancer        2024-03-14
# 9998   ReBeccA ramos ddS   71         A-      Hypertension        2023-08-22
# 9999  rebeCCA stEPHenSOn   24         A+      Hypertension        2023-04-24
#
#                 Doctor                       Hospital Insurance Provider  \
# 0        Matthew Smith                Sons and Miller         Blue Cross
# 1      Samantha Davies                        Kim Inc           Medicare
# 2     Tiffany Mitchell                       Cook PLC              Aetna
# 3          Kevin Wells     Hernandez Rogers and Vang,           Medicare
# 4       Kathleen Hanna                    White-White              Aetna
# ...                ...                            ...                ...
# 9995       Isaac Silva                  Rice and Sons              Cigna
# 9996        Jose Cohen   Johnson, Adkins and Ferguson              Aetna
# 9997      Michael Hess                   Kramer-Hogan   UnitedHealthcare
# 9998   Cheryl Faulkner  Williams Barnes and Fletcher,         Blue Cross
# 9999    Jonathan Owens                      Jones Ltd              Cigna
#
#       Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# 0       18856.281306          328         Urgent     2024-02-02  Paracetamol
# 1       33643.327287          265      Emergency     2019-08-26    Ibuprofen
# 2       27955.096079          205      Emergency     2022-10-07      Aspirin
# 3       37909.782410          450       Elective     2020-12-18    Ibuprofen
# 4       14238.317814          458         Urgent     2022-10-09   Penicillin
# ...              ...          ...            ...            ...          ...
# 9995     5127.438142          106         Urgent     2019-10-03    Ibuprofen
# 9996    47855.349591          122      Emergency     2020-06-04  Paracetamol
# 9997    40787.180500          440       Elective     2024-03-28   Penicillin
# 9998    25979.751629          319      Emergency     2023-09-03      Lipitor
# 9999    19782.638991          438      Emergency     2023-05-23    Ibuprofen
#
#       Test Results Age Range  Patient ID
# 0           Normal     30-44         NaN
# 1     Inconclusive       60+         NaN
# 2           Normal       60+         NaN
# 3         Abnormal     18-29         NaN
# 4         Abnormal     30-44         NaN
# ...            ...       ...         ...
# 9995        Normal     45-59         NaN
# 9996        Normal       60+         NaN
# 9997  Inconclusive     18-29         NaN
# 9998  Inconclusive       60+         NaN
# 9999  Inconclusive     18-29         NaN
#
# [10000 rows x 16 columns]

# %%
df = df[["Name", "Patient ID", "Age", "Age Range", "Blood Type", "Medical Condition", "Date of Admission", "Discharge Date", "Billing Amount", "Doctor", "Hospital", "Room Number", "Insurance Provider", "Medication", "Test Results", "Admission Type", ]]

# %%
df
# Out:
#                     Name  Patient ID  Age Age Range Blood Type  \
# 0          Bobby JacksOn         NaN   30     30-44         B-
# 1           LesLie TErRy         NaN   62       60+         A+
# 2            DaNnY sMitH         NaN   76       60+         A-
# 3           andrEw waTtS         NaN   28     18-29         O+
# 4          adrIENNE bEll         NaN   43     30-44        AB+
# ...                  ...         ...  ...       ...        ...
# 9995         David JoNEs         NaN   51     45-59         O-
# 9996       NICOle BRooKS         NaN   61       60+         B-
# 9997         MIKE TayloR         NaN   25     18-29         B-
# 9998   ReBeccA ramos ddS         NaN   71       60+         A-
# 9999  rebeCCA stEPHenSOn         NaN   24     18-29         A+
#
#      Medical Condition Date of Admission Discharge Date  Billing Amount  \
# 0               Cancer        2024-01-31     2024-02-02    18856.281306
# 1              Obesity        2019-08-20     2019-08-26    33643.327287
# 2              Obesity        2022-09-22     2022-10-07    27955.096079
# 3             Diabetes        2020-11-18     2020-12-18    37909.782410
# 4               Cancer        2022-09-19     2022-10-09    14238.317814
# ...                ...               ...            ...             ...
# 9995         Arthritis        2019-09-25     2019-10-03     5127.438142
# 9996          Diabetes        2020-06-03     2020-06-04    47855.349591
# 9997            Cancer        2024-03-14     2024-03-28    40787.180500
# 9998      Hypertension        2023-08-22     2023-09-03    25979.751629
# 9999      Hypertension        2023-04-24     2023-05-23    19782.638991
#
#                 Doctor                       Hospital  Room Number  \
# 0        Matthew Smith                Sons and Miller          328
# 1      Samantha Davies                        Kim Inc          265
# 2     Tiffany Mitchell                       Cook PLC          205
# 3          Kevin Wells     Hernandez Rogers and Vang,          450
# 4       Kathleen Hanna                    White-White          458
# ...                ...                            ...          ...
# 9995       Isaac Silva                  Rice and Sons          106
# 9996        Jose Cohen   Johnson, Adkins and Ferguson          122
# 9997      Michael Hess                   Kramer-Hogan          440
# 9998   Cheryl Faulkner  Williams Barnes and Fletcher,          319
# 9999    Jonathan Owens                      Jones Ltd          438
#
#      Insurance Provider   Medication  Test Results Admission Type
# 0            Blue Cross  Paracetamol        Normal         Urgent
# 1              Medicare    Ibuprofen  Inconclusive      Emergency
# 2                 Aetna      Aspirin        Normal      Emergency
# 3              Medicare    Ibuprofen      Abnormal       Elective
# 4                 Aetna   Penicillin      Abnormal         Urgent
# ...                 ...          ...           ...            ...
# 9995              Cigna    Ibuprofen        Normal         Urgent
# 9996              Aetna  Paracetamol        Normal      Emergency
# 9997   UnitedHealthcare   Penicillin  Inconclusive       Elective
# 9998         Blue Cross      Lipitor  Inconclusive      Emergency
# 9999              Cigna    Ibuprofen  Inconclusive      Emergency
#
# [10000 rows x 16 columns]

# %% [markdown]
# Here I have organised the columns in the data frame, to make it easier to read.

# %%
df['Name'] = df['Name'].str.lower()

# %%
df
# Out:
#                     Name  Patient ID  Age Age Range Blood Type  \
# 0          bobby jackson         NaN   30     30-44         B-
# 1           leslie terry         NaN   62       60+         A+
# 2            danny smith         NaN   76       60+         A-
# 3           andrew watts         NaN   28     18-29         O+
# 4          adrienne bell         NaN   43     30-44        AB+
# ...                  ...         ...  ...       ...        ...
# 9995         david jones         NaN   51     45-59         O-
# 9996       nicole brooks         NaN   61       60+         B-
# 9997         mike taylor         NaN   25     18-29         B-
# 9998   rebecca ramos dds         NaN   71       60+         A-
# 9999  rebecca stephenson         NaN   24     18-29         A+
#
#      Medical Condition Date of Admission Discharge Date  Billing Amount  \
# 0               Cancer        2024-01-31     2024-02-02    18856.281306
# 1              Obesity        2019-08-20     2019-08-26    33643.327287
# 2              Obesity        2022-09-22     2022-10-07    27955.096079
# 3             Diabetes        2020-11-18     2020-12-18    37909.782410
# 4               Cancer        2022-09-19     2022-10-09    14238.317814
# ...                ...               ...            ...             ...
# 9995         Arthritis        2019-09-25     2019-10-03     5127.438142
# 9996          Diabetes        2020-06-03     2020-06-04    47855.349591
# 9997            Cancer        2024-03-14     2024-03-28    40787.180500
# 9998      Hypertension        2023-08-22     2023-09-03    25979.751629
# 9999      Hypertension        2023-04-24     2023-05-23    19782.638991
#
#                 Doctor                       Hospital  Room Number  \
# 0        Matthew Smith                Sons and Miller          328
# 1      Samantha Davies                        Kim Inc          265
# 2     Tiffany Mitchell                       Cook PLC          205
# 3          Kevin Wells     Hernandez Rogers and Vang,          450
# 4       Kathleen Hanna                    White-White          458
# ...                ...                            ...          ...
# 9995       Isaac Silva                  Rice and Sons          106
# 9996        Jose Cohen   Johnson, Adkins and Ferguson          122
# 9997      Michael Hess                   Kramer-Hogan          440
# 9998   Cheryl Faulkner  Williams Barnes and Fletcher,          319
# 9999    Jonathan Owens                      Jones Ltd          438
#
#      Insurance Provider   Medication  Test Results Admission Type
# 0            Blue Cross  Paracetamol        Normal         Urgent
# 1              Medicare    Ibuprofen  Inconclusive      Emergency
# 2                 Aetna      Aspirin        Normal      Emergency
# 3              Medicare    Ibuprofen      Abnormal       Elective
# 4                 Aetna   Penicillin      Abnormal         Urgent
# ...                 ...          ...           ...            ...
# 9995              Cigna    Ibuprofen        Normal         Urgent
# 9996              Aetna  Paracetamol        Normal      Emergency
# 9997   UnitedHealthcare   Penicillin  Inconclusive       Elective
# 9998         Blue Cross      Lipitor  Inconclusive      Emergency
# 9999              Cigna    Ibuprofen  Inconclusive      Emergency
#
# [10000 rows x 16 columns]

# %%
df["Name"] = df["Name"].str.title()

# %%
df
# Out:
#                     Name  Patient ID  Age Age Range Blood Type  \
# 0          Bobby Jackson         NaN   30     30-44         B-
# 1           Leslie Terry         NaN   62       60+         A+
# 2            Danny Smith         NaN   76       60+         A-
# 3           Andrew Watts         NaN   28     18-29         O+
# 4          Adrienne Bell         NaN   43     30-44        AB+
# ...                  ...         ...  ...       ...        ...
# 9995         David Jones         NaN   51     45-59         O-
# 9996       Nicole Brooks         NaN   61       60+         B-
# 9997         Mike Taylor         NaN   25     18-29         B-
# 9998   Rebecca Ramos Dds         NaN   71       60+         A-
# 9999  Rebecca Stephenson         NaN   24     18-29         A+
#
#      Medical Condition Date of Admission Discharge Date  Billing Amount  \
# 0               Cancer        2024-01-31     2024-02-02    18856.281306
# 1              Obesity        2019-08-20     2019-08-26    33643.327287
# 2              Obesity        2022-09-22     2022-10-07    27955.096079
# 3             Diabetes        2020-11-18     2020-12-18    37909.782410
# 4               Cancer        2022-09-19     2022-10-09    14238.317814
# ...                ...               ...            ...             ...
# 9995         Arthritis        2019-09-25     2019-10-03     5127.438142
# 9996          Diabetes        2020-06-03     2020-06-04    47855.349591
# 9997            Cancer        2024-03-14     2024-03-28    40787.180500
# 9998      Hypertension        2023-08-22     2023-09-03    25979.751629
# 9999      Hypertension        2023-04-24     2023-05-23    19782.638991
#
#                 Doctor                       Hospital  Room Number  \
# 0        Matthew Smith                Sons and Miller          328
# 1      Samantha Davies                        Kim Inc          265
# 2     Tiffany Mitchell                       Cook PLC          205
# 3          Kevin Wells     Hernandez Rogers and Vang,          450
# 4       Kathleen Hanna                    White-White          458
# ...                ...                            ...          ...
# 9995       Isaac Silva                  Rice and Sons          106
# 9996        Jose Cohen   Johnson, Adkins and Ferguson          122
# 9997      Michael Hess                   Kramer-Hogan          440
# 9998   Cheryl Faulkner  Williams Barnes and Fletcher,          319
# 9999    Jonathan Owens                      Jones Ltd          438
#
#      Insurance Provider   Medication  Test Results Admission Type
# 0            Blue Cross  Paracetamol        Normal         Urgent
# 1              Medicare    Ibuprofen  Inconclusive      Emergency
# 2                 Aetna      Aspirin        Normal      Emergency
# 3              Medicare    Ibuprofen      Abnormal       Elective
# 4                 Aetna   Penicillin      Abnormal         Urgent
# ...                 ...          ...           ...            ...
# 9995              Cigna    Ibuprofen        Normal         Urgent
# 9996              Aetna  Paracetamol        Normal      Emergency
# 9997   UnitedHealthcare   Penicillin  Inconclusive       Elective
# 9998         Blue Cross      Lipitor  Inconclusive      Emergency
# 9999              Cigna    Ibuprofen  Inconclusive      Emergency
#
# [10000 rows x 16 columns]

# %% [markdown]
# Here I have lowered the case for the names, then titled them, so they fit the same capitalizations.

# %%
for i in df.index:
    pid = random.randint(1_000_000_000, 10_000_000_000)
    df.loc[i, "Patient ID"] = str(pid)
# Out:
# C:\Users\matte\AppData\Local\Temp\ipykernel_25360\1242190293.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '9376641303' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[i, "Patient ID"] = str(pid)

# %%
df
# Out:
#                     Name  Patient ID  Age Age Range Blood Type  \
# 0          Bobby Jackson  9376641303   30     30-44         B-
# 1           Leslie Terry  8430993907   62       60+         A+
# 2            Danny Smith  3603728862   76       60+         A-
# 3           Andrew Watts  2137475067   28     18-29         O+
# 4          Adrienne Bell  8266987582   43     30-44        AB+
# ...                  ...         ...  ...       ...        ...
# 9995         David Jones  1584964760   51     45-59         O-
# 9996       Nicole Brooks  9549826269   61       60+         B-
# 9997         Mike Taylor  4278239584   25     18-29         B-
# 9998   Rebecca Ramos Dds  1555299601   71       60+         A-
# 9999  Rebecca Stephenson  8981898657   24     18-29         A+
#
#      Medical Condition Date of Admission Discharge Date  Billing Amount  \
# 0               Cancer        2024-01-31     2024-02-02    18856.281306
# 1              Obesity        2019-08-20     2019-08-26    33643.327287
# 2              Obesity        2022-09-22     2022-10-07    27955.096079
# 3             Diabetes        2020-11-18     2020-12-18    37909.782410
# 4               Cancer        2022-09-19     2022-10-09    14238.317814
# ...                ...               ...            ...             ...
# 9995         Arthritis        2019-09-25     2019-10-03     5127.438142
# 9996          Diabetes        2020-06-03     2020-06-04    47855.349591
# 9997            Cancer        2024-03-14     2024-03-28    40787.180500
# 9998      Hypertension        2023-08-22     2023-09-03    25979.751629
# 9999      Hypertension        2023-04-24     2023-05-23    19782.638991
#
#                 Doctor                       Hospital  Room Number  \
# 0        Matthew Smith                Sons and Miller          328
# 1      Samantha Davies                        Kim Inc          265
# 2     Tiffany Mitchell                       Cook PLC          205
# 3          Kevin Wells     Hernandez Rogers and Vang,          450
# 4       Kathleen Hanna                    White-White          458
# ...                ...                            ...          ...
# 9995       Isaac Silva                  Rice and Sons          106
# 9996        Jose Cohen   Johnson, Adkins and Ferguson          122
# 9997      Michael Hess                   Kramer-Hogan          440
# 9998   Cheryl Faulkner  Williams Barnes and Fletcher,          319
# 9999    Jonathan Owens                      Jones Ltd          438
#
#      Insurance Provider   Medication  Test Results Admission Type
# 0            Blue Cross  Paracetamol        Normal         Urgent
# 1              Medicare    Ibuprofen  Inconclusive      Emergency
# 2                 Aetna      Aspirin        Normal      Emergency
# 3              Medicare    Ibuprofen      Abnormal       Elective
# 4                 Aetna   Penicillin      Abnormal         Urgent
# ...                 ...          ...           ...            ...
# 9995              Cigna    Ibuprofen        Normal         Urgent
# 9996              Aetna  Paracetamol        Normal      Emergency
# 9997   UnitedHealthcare   Penicillin  Inconclusive       Elective
# 9998         Blue Cross      Lipitor  Inconclusive      Emergency
# 9999              Cigna    Ibuprofen  Inconclusive      Emergency
#
# [10000 rows x 16 columns]

# %% [markdown]
# Here I have added a random 10 digit number as a patient ID, so I can delete the names for ethics reasons. I plan to make some code to allow me to check to see if the Patient ID column has any duplicates in it and rerun the code if it does.

# %%
df["Billing Amount"] = df["Billing Amount"].round(2)

# %%
df
# Out:
#                     Name  Patient ID  Age Age Range Blood Type  \
# 0          Bobby Jackson  9376641303   30     30-44         B-
# 1           Leslie Terry  8430993907   62       60+         A+
# 2            Danny Smith  3603728862   76       60+         A-
# 3           Andrew Watts  2137475067   28     18-29         O+
# 4          Adrienne Bell  8266987582   43     30-44        AB+
# ...                  ...         ...  ...       ...        ...
# 9995         David Jones  1584964760   51     45-59         O-
# 9996       Nicole Brooks  9549826269   61       60+         B-
# 9997         Mike Taylor  4278239584   25     18-29         B-
# 9998   Rebecca Ramos Dds  1555299601   71       60+         A-
# 9999  Rebecca Stephenson  8981898657   24     18-29         A+
#
#      Medical Condition Date of Admission Discharge Date  Billing Amount  \
# 0               Cancer        2024-01-31     2024-02-02        18856.28
# 1              Obesity        2019-08-20     2019-08-26        33643.33
# 2              Obesity        2022-09-22     2022-10-07        27955.10
# 3             Diabetes        2020-11-18     2020-12-18        37909.78
# 4               Cancer        2022-09-19     2022-10-09        14238.32
# ...                ...               ...            ...             ...
# 9995         Arthritis        2019-09-25     2019-10-03         5127.44
# 9996          Diabetes        2020-06-03     2020-06-04        47855.35
# 9997            Cancer        2024-03-14     2024-03-28        40787.18
# 9998      Hypertension        2023-08-22     2023-09-03        25979.75
# 9999      Hypertension        2023-04-24     2023-05-23        19782.64
#
#                 Doctor                       Hospital  Room Number  \
# 0        Matthew Smith                Sons and Miller          328
# 1      Samantha Davies                        Kim Inc          265
# 2     Tiffany Mitchell                       Cook PLC          205
# 3          Kevin Wells     Hernandez Rogers and Vang,          450
# 4       Kathleen Hanna                    White-White          458
# ...                ...                            ...          ...
# 9995       Isaac Silva                  Rice and Sons          106
# 9996        Jose Cohen   Johnson, Adkins and Ferguson          122
# 9997      Michael Hess                   Kramer-Hogan          440
# 9998   Cheryl Faulkner  Williams Barnes and Fletcher,          319
# 9999    Jonathan Owens                      Jones Ltd          438
#
#      Insurance Provider   Medication  Test Results Admission Type
# 0            Blue Cross  Paracetamol        Normal         Urgent
# 1              Medicare    Ibuprofen  Inconclusive      Emergency
# 2                 Aetna      Aspirin        Normal      Emergency
# 3              Medicare    Ibuprofen      Abnormal       Elective
# 4                 Aetna   Penicillin      Abnormal         Urgent
# ...                 ...          ...           ...            ...
# 9995              Cigna    Ibuprofen        Normal         Urgent
# 9996              Aetna  Paracetamol        Normal      Emergency
# 9997   UnitedHealthcare   Penicillin  Inconclusive       Elective
# 9998         Blue Cross      Lipitor  Inconclusive      Emergency
# 9999              Cigna    Ibuprofen  Inconclusive      Emergency
#
# [10000 rows x 16 columns]

# %% [markdown]
# Here I have rounded the billing amount to 2 decimal places to fit most currencies in the world. Will change if needed later.

# %%
df.drop(columns=["Name"], inplace=True)

# %%
df
# Out:
#       Patient ID  Age Age Range Blood Type Medical Condition  \
# 0     9376641303   30     30-44         B-            Cancer
# 1     8430993907   62       60+         A+           Obesity
# 2     3603728862   76       60+         A-           Obesity
# 3     2137475067   28     18-29         O+          Diabetes
# 4     8266987582   43     30-44        AB+            Cancer
# ...          ...  ...       ...        ...               ...
# 9995  1584964760   51     45-59         O-         Arthritis
# 9996  9549826269   61       60+         B-          Diabetes
# 9997  4278239584   25     18-29         B-            Cancer
# 9998  1555299601   71       60+         A-      Hypertension
# 9999  8981898657   24     18-29         A+      Hypertension
#
#      Date of Admission Discharge Date  Billing Amount            Doctor  \
# 0           2024-01-31     2024-02-02        18856.28     Matthew Smith
# 1           2019-08-20     2019-08-26        33643.33   Samantha Davies
# 2           2022-09-22     2022-10-07        27955.10  Tiffany Mitchell
# 3           2020-11-18     2020-12-18        37909.78       Kevin Wells
# 4           2022-09-19     2022-10-09        14238.32    Kathleen Hanna
# ...                ...            ...             ...               ...
# 9995        2019-09-25     2019-10-03         5127.44       Isaac Silva
# 9996        2020-06-03     2020-06-04        47855.35        Jose Cohen
# 9997        2024-03-14     2024-03-28        40787.18      Michael Hess
# 9998        2023-08-22     2023-09-03        25979.75   Cheryl Faulkner
# 9999        2023-04-24     2023-05-23        19782.64    Jonathan Owens
#
#                            Hospital  Room Number Insurance Provider  \
# 0                   Sons and Miller          328         Blue Cross
# 1                           Kim Inc          265           Medicare
# 2                          Cook PLC          205              Aetna
# 3        Hernandez Rogers and Vang,          450           Medicare
# 4                       White-White          458              Aetna
# ...                             ...          ...                ...
# 9995                  Rice and Sons          106              Cigna
# 9996   Johnson, Adkins and Ferguson          122              Aetna
# 9997                   Kramer-Hogan          440   UnitedHealthcare
# 9998  Williams Barnes and Fletcher,          319         Blue Cross
# 9999                      Jones Ltd          438              Cigna
#
#        Medication  Test Results Admission Type
# 0     Paracetamol        Normal         Urgent
# 1       Ibuprofen  Inconclusive      Emergency
# 2         Aspirin        Normal      Emergency
# 3       Ibuprofen      Abnormal       Elective
# 4      Penicillin      Abnormal         Urgent
# ...           ...           ...            ...
# 9995    Ibuprofen        Normal         Urgent
# 9996  Paracetamol        Normal      Emergency
# 9997   Penicillin  Inconclusive       Elective
# 9998      Lipitor  Inconclusive      Emergency
# 9999    Ibuprofen  Inconclusive      Emergency
#
# [10000 rows x 15 columns]

# %% [markdown]
# Here I have dropped the names for ethics reasons.
# 1) The names are not important to visualisations
# 2) Becuase others may access the dataset, anonamyising the names with the 10 digit number means that less is likely to be breached

# %%
def create_download_link(df, title="healthcare_cleaned.csv", filename="healthcare_cleaned.csv"):
    """Generates a link to download the data in a given pandas DataFrame"""
    csv = df.to_csv()
    b64 = base64.b64encode(csv.encode())
    payload = b64.decode()
    html = '<a download="{filename}" href="data:text/csv;base64,{payload}" target="_blank">{title}</a>'
    html = html.format(payload=payload, title=title, filename=filename)
    return HTML(html)
create_download_link(df)
# Out:
# <a download="healthcare_cleaned.csv" href="data:text/csv;base64,..." target="_blank">healthcare_cleaned.csv</a>

# %%
def create_download_link_xlsx(df, title="healthcare_cleaned.xlsx", filename="healthcare_cleaned.xlsx"):
    """Generates a link to download the data in a given pandas DataFrame as XLSX"""
    towrite = io.BytesIO()
    df.to_excel(towrite, index=False)
    towrite.seek(0)
    b64 = base64.b64encode(towrite.read()).decode()
    html = f'<a download="{filename}" href="data:application/vnd.openxmlformats-officedocument.spreadsheetml.sheet;base64,{b64}" target="_blank">{title}</a>'
    return HTML(html)
create_download_link_xlsx(df)
# Out:
# <a download="healthcare_cleaned.xlsx" href="data:application/vnd.openxmlformats-officedocument.spreadsheetml.sheet;base64,..." target="_blank">healthcare_cleaned.xlsx</a>

# %% [markdown]
# Here are downloadable copies of the dataset, this allows me to access it in Power Bi and another notebook a lot easier. I was having an issue with the code, so I asked ChatGPT what the problem was, and it was that I had forgotten to import the libraries when adding in this code

# %%
df["Billing Amount"].median()
# Out:
# np.float64(25633.06)

# %% [markdown]
# Here is the median cost we are billing the patients

# %%
df["Billing Amount"].mode()[0]
# Out:
# np.float64(2106.39)

# %% [markdown]
# Here is the mode of the billing amount

# %%
start = df["Date of Admission"].min()
end = df["Discharge Date"].max()
print("Date range from", start, "to", end)
# Out:
# Date range from 2019-05-08 to 2024-06-02

# %% [markdown]
# Here is the total range from the earliest patient entery, to the last patient leaving

# %%
std = df["Billing Amount"].std()
print("Standard Deviation of Billing Amount:", std)
# Out:
# Standard Deviation of Billing Amount: 14187.175237645011

# %% [markdown]
# Here is the standard deviation for the billing amount
